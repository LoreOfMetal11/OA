# %% [markdown]
# ## Вторая лабораторная работа. Табличные данные.
#
# **Цель:** загрузить выбранную мною выборку и провести над ней определенные операции.
#
# **Требования к отчету:**
# - работа в формате Jupyter Notebook (интерактивный отчет);
# - загрузка выборки с GitHub'a;
# - описание выбранного датасета (содержание строк и назначение столбцов);
# - выполнение задания на 4 уровня.

# %%
# !git clone https://github.com/LoreOfMetal11/OA
# !ls OA

import pandas as pd
import numpy as np
# Out:
# fatal: destination path 'OA' already exists and is not an empty directory.
# README.md  weatherAUS.csv

# %% [markdown]
# ## Описание выборки
#
# Выборка содержит данные о погоде в различных городах Австралии. Каждая строка таблицы представляет результаты наблюдения за погодой в определенном городе за конкретную дату.
#
# В таблице представлены следующие признаки:
#
# - **Date** - дата проведения наблюдения.
# - **Location** - название города или метеорологической станции, в которой проводилось наблюдение.
# - **MinTemp** - минимальная температура воздуха за сутки в градусах Цельсия.
# - **MaxTemp** - максимальная температура воздуха за сутки в градусах Цельсия.
# - **Rainfall** - количество осадков, выпавших за сутки, в миллиметрах.
# - **Evaporation** - количество испарившейся воды за сутки в миллиметрах.
# - **Sunshine** - продолжительность солнечного сияния за сутки в часах.
# - **WindGustDir** - направление самого сильного порыва ветра.
# - **WindGustSpeed** - скорость самого сильного порыва ветра в километрах в час.
# - **WindDir9am** - направление ветра в 9 часов утра.
# - **WindDir3pm** - направление ветра в 3 часа дня.
# - **WindSpeed9am** - скорость ветра в 9 часов утра в километрах в час.
# - **WindSpeed3pm** - скорость ветра в 3 часа дня в километрах в час.
# - **Humidity9am** - относительная влажность воздуха в 9 часов утра в процентах.
# - **Humidity3pm** - относительная влажность воздуха в 3 часа дня в процентах.
# - **Pressure9am** - атмосферное давление в 9 часов утра в гектопаскалях.
# - **Pressure3pm** - атмосферное давление в 3 часа дня в гектопаскалях.
# - **Cloud9am** - облачность в 9 часов утра. Значение показывает долю неба, покрытую облаками.
# - **Cloud3pm** - облачность в 3 часа дня. Значение показывает долю неба, покрытую облаками.
# - **Temp9am** - температура воздуха в 9 часов утра в градусах Цельсия.
# - **Temp3pm** - температура воздуха в 3 часа дня в градусах Цельсия.
# - **RainToday** - бинарный признак, показывающий, был ли дождь в этот день: `Yes` - дождь был, `No` - дождя не было.
# - **RainTomorrow** - бинарный признак, показывающий, будет ли дождь на следующий день: `Yes` - дождь будет, `No` - дождя не будет.
#
# Столбец **RainTomorrow** может использоваться как целевая переменная при решении задачи классификации. Остальные столбцы являются признаками, на основе которых можно прогнозировать наличие дождя на следующий день.

# %%
data = pd.read_csv('OA/weatherAUS.csv', delimiter=',')
data
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %% [markdown]
# ## Практическая часть (обязательная часть)

# %% [markdown]
# 1. Вывод первых 5 строк таблицы.

# %%
data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# 2. Определение размерности таблицы

# %%
data.shape
# Out:
# (145460, 23)

# %% [markdown]
# 3. Просмотр типов данных стлобцов

# %%
data.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %% [markdown]
# 4. Вывод типов данных

# %% [markdown]
# Вывод числовых данных

# %%
data.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %% [markdown]
# Вывод строковых данных

# %%
data.describe(include='O')
# Out:
#               Date  Location WindGustDir WindDir9am WindDir3pm RainToday  \
# count       145460    145460      135134     134894     141232    142199
# unique        3436        49          16         16         16         2
# top     2017-06-24  Canberra           W          N         SE        No
# freq            49      3436        9915      11758      10838    110319
#
#        RainTomorrow
# count        142193
# unique            2
# top              No
# freq         110316

# %% [markdown]
# 5. Определить числовые и категориальных столбцов

# %% [markdown]
# Числовые столбцы типа `float64`: `MinTemp`, `MaxTemp`, `Rainfall`, `Sunshine`, `WindGustSpeed`, `WindSpeed9am`, `WindSpeed3pm`, `Humidity9am`, `Humidity3pm`, `Pressure9am`, `Pressure3pm`, `Cloud9am`, `Cloud3pm`, `Temp9am`, `Temp3pm`.
#
# Категориальные столбцы типа `object`: `Location`, `WindGustDir`, `WindDir9am`, `WindDir3pm`, `RainToday`, `RainTomorrow`.

# %% [markdown]
# ## Базовый уровень.

# %% [markdown]
# 1. Получить описательную статистику числовых признаков

# %%
#Минимальные признаки
data.describe().loc['min']
# Out:
# MinTemp           -8.5
# MaxTemp           -4.8
# Rainfall           0.0
# Evaporation        0.0
# Sunshine           0.0
# WindGustSpeed      6.0
# WindSpeed9am       0.0
# WindSpeed3pm       0.0
# Humidity9am        0.0
# Humidity3pm        0.0
# Pressure9am      980.5
# Pressure3pm      977.1
# Cloud9am           0.0
# Cloud3pm           0.0
# Temp9am           -7.2
# Temp3pm           -5.4
# Name: min, dtype: float64

# %%
#Максимальные признаки
data.describe().loc['max']
# Out:
# MinTemp            33.9
# MaxTemp            48.1
# Rainfall          371.0
# Evaporation       145.0
# Sunshine           14.5
# WindGustSpeed     135.0
# WindSpeed9am      130.0
# WindSpeed3pm       87.0
# Humidity9am       100.0
# Humidity3pm       100.0
# Pressure9am      1041.0
# Pressure3pm      1039.6
# Cloud9am            9.0
# Cloud3pm            9.0
# Temp9am            40.2
# Temp3pm            46.7
# Name: max, dtype: float64

# %%
#Среднее значение
data.describe().loc['mean']
# Out:
# MinTemp            12.194034
# MaxTemp            23.221348
# Rainfall            2.360918
# Evaporation         5.468232
# Sunshine            7.611178
# WindGustSpeed      40.035230
# WindSpeed9am       14.043426
# WindSpeed3pm       18.662657
# Humidity9am        68.880831
# Humidity3pm        51.539116
# Pressure9am      1017.649940
# Pressure3pm      1015.255889
# Cloud9am            4.447461
# Cloud3pm            4.509930
# Temp9am            16.990631
# Temp3pm            21.683390
# Name: mean, dtype: float64

# %%
#Вывести разброс
data.describe().loc['std']
# Out:
# MinTemp           6.398495
# MaxTemp           7.119049
# Rainfall          8.478060
# Evaporation       4.193704
# Sunshine          3.785483
# WindGustSpeed    13.607062
# WindSpeed9am      8.915375
# WindSpeed3pm      8.809800
# Humidity9am      19.029164
# Humidity3pm      20.795902
# Pressure9am       7.106530
# Pressure3pm       7.037414
# Cloud9am          2.887159
# Cloud3pm          2.720357
# Temp9am           6.488753
# Temp3pm           6.936650
# Name: std, dtype: float64

# %%
#Вывести наибольший разрыв (может просто вывести std в порядке убывания)
data.describe().loc['max'] - data.describe().loc['min']
# Out:
# MinTemp           42.4
# MaxTemp           52.9
# Rainfall         371.0
# Evaporation      145.0
# Sunshine          14.5
# WindGustSpeed    129.0
# WindSpeed9am     130.0
# WindSpeed3pm      87.0
# Humidity9am      100.0
# Humidity3pm      100.0
# Pressure9am       60.5
# Pressure3pm       62.5
# Cloud9am           9.0
# Cloud3pm           9.0
# Temp9am           47.4
# Temp3pm           52.1
# dtype: float64

# %% [markdown]
# 2. Наиболее вариативные и стабильные признаки

# %%
data.describe().loc['std'].sort_values(ascending=False)
# Out:
# Humidity3pm      20.795902
# Humidity9am      19.029164
# WindGustSpeed    13.607062
# WindSpeed9am      8.915375
# WindSpeed3pm      8.809800
# Rainfall          8.478060
# MaxTemp           7.119049
# Pressure9am       7.106530
# Pressure3pm       7.037414
# Temp3pm           6.936650
# Temp9am           6.488753
# MinTemp           6.398495
# Evaporation       4.193704
# Sunshine          3.785483
# Cloud9am          2.887159
# Cloud3pm          2.720357
# Name: std, dtype: float64

# %% [markdown]
# Наиболее вариативными являются признаки с наибольшим стандартным отклонением: `Humidity3pm` (std = 20.80), `Humidity9am` (std = 19.03), `WindGustSpeed` (std = 13.61), `WindSpeed9am` (std = 8.92), `WindSpeed3pm` (std = 8.81) и `Rainfall` (std = 8.48). Эти признаки имеют std больше 8.
#
# Наиболее стабильными являются признаки с наименьшим стандартным отклонением: `Cloud3pm` (std = 2.72), `Cloud9am` (std = 2.89), `Sunshine` (std = 3.79), `Evaporation` (std = 4.19), `MinTemp` (std = 6.40), `Temp9am` (std = 6.49), `Temp3pm` (std = 6.94), `Pressure3pm` (std = 7.04), `Pressure9am` (std = 7.11) и `MaxTemp` (std = 7.12). Эти признаки имеют std меньше 8.

# %% [markdown]
# 3. Выполнить фильтрацию данных по одному условию

# %%
filtered_data = data[data.Rainfall > 20]
filtered_data
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 146     2009-04-26   Albury      8.6     12.9      21.0          NaN
# 296     2009-09-23   Albury      9.3     16.8      28.8          NaN
# 356     2009-11-22   Albury     18.3     28.3      25.8          NaN
# 431     2010-02-05   Albury     19.2     26.1      52.2          NaN
# 460     2010-03-06   Albury     18.8     30.3      20.6          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145276  2016-12-24    Uluru     22.9     29.9      21.8          NaN
# 145278  2016-12-26    Uluru     22.1     27.4      83.8          NaN
# 145279  2016-12-27    Uluru     22.1     35.8      63.8          NaN
# 145295  2017-01-12    Uluru     21.6     34.1      23.6          NaN
# 145393  2017-04-20    Uluru     18.6     28.6      34.6          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %% [markdown]
# 4. Отсортировать по возрастанию/убыванию

# %%
filtered_data.sort_values(by='Rainfall').head(1000)
# Out:
#               Date     Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 145044  2016-05-06        Uluru     18.0     21.6      20.2          NaN
# 30650   2009-05-20       Sydney     14.5     21.2      20.2          4.4
# 12708   2010-10-04        Moree     14.7     26.6      20.2          1.8
# 109455  2011-06-03       Albany     10.6     16.0      20.2          2.0
# 49938   2011-07-04  Tuggeranong      3.0     13.0      20.2          NaN
# ...            ...          ...      ...      ...       ...          ...
# 84014   2008-07-08     Brisbane     14.5     17.4      24.2          2.0
# 76797   2014-03-22     Portland      9.7     15.1      24.2          1.2
# 91733   2013-04-01    GoldCoast     19.8     27.5      24.2          NaN
# 92273   2014-09-23    GoldCoast     15.5     23.4      24.2          NaN
# 37981   2013-03-22   WaggaWagga     15.1     24.4      24.2          1.4
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
filtered_data.sort_values(by='Rainfall', ascending=False).head(1000)
# Out:
#               Date      Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 9368    2009-11-07  CoffsHarbour     17.4     23.1     371.0          NaN
# 140071  2011-02-16        Darwin     22.1     25.6     367.6          NaN
# 87242   2009-01-12        Cairns     22.3     27.4     278.4          NaN
# 87995   2011-02-04        Cairns     22.9     29.9     268.6          NaN
# 89371   2015-02-08        Cairns     23.8     31.0     247.2          NaN
# ...            ...           ...      ...      ...       ...          ...
# 116525  2014-06-18    PearceRAAF     10.9     17.8      45.0          NaN
# 139279  2008-12-16        Darwin     23.7     29.1      44.8         10.4
# 24560   2010-02-07       Penrith     19.5     25.4      44.8          NaN
# 93324   2009-01-14    Townsville     23.1     28.3      44.8          NaN
# 94051   2011-01-11    Townsville     23.5     30.4      44.8          6.0
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %% [markdown]
# ## Средний уровень

# %% [markdown]
# 1. Группировка по одному категориальному признаку

# %%
group_loc = data.groupby('Location')
#2. Рассчет для каждой группы среднее, максимальное, минимальное зачение и кол-во объектов
group_loc['MaxTemp'].mean().sort_values(ascending=False)
# Out:
# Location
# Katherine           34.935436
# Darwin              32.540977
# Uluru               30.383195
# Cairns              29.558849
# Townsville          29.367160
# AliceSprings        29.248420
# Moree               26.950548
# Woomera             26.596707
# Brisbane            26.448380
# PearceRAAF          26.051238
# Cobar               25.870093
# GoldCoast           25.767062
# PerthAirport        25.533234
# Perth               25.034837
# Mildura             24.840944
# Penrith             24.764366
# Richmond            24.458664
# SalmonGums          24.250827
# Newcastle           24.101070
# BadgerysCreek       24.031208
# Williamtown         24.001065
# CoffsHarbour        23.965385
# SydneyAirport       23.383915
# WaggaWagga          23.031871
# Sydney              23.001975
# Adelaide            22.898934
# Albury              22.640872
# NorahHead           22.588937
# Nhil                22.405153
# NorfolkIsland       21.830253
# ...

# %%
group_loc['MaxTemp'].min().sort_values(ascending=True)
# Out:
# Location
# MountGinini         -4.8
# Tuggeranong          2.6
# Canberra             4.1
# Ballarat             4.6
# WaggaWagga           6.3
# Albury               6.8
# AliceSprings         7.0
# Dartmoor             7.1
# Bendigo              7.1
# Hobart               7.2
# Launceston           7.8
# Cobar                7.8
# MountGambier         8.2
# MelbourneAirport     8.4
# Nhil                 8.6
# Nuriootpa            8.7
# Sale                 8.7
# Portland             9.0
# Mildura              9.1
# Watsonia             9.1
# Richmond             9.5
# Moree                9.6
# Melbourne            9.7
# SalmonGums          10.7
# Adelaide            10.8
# Walpole             11.2
# Penrith             11.2
# Woomera             11.2
# Uluru               11.3
# BadgerysCreek       11.3
# Witchcliffe         11.5
# PearceRAAF          11.6
# Albany              11.6
# SydneyAirport       11.6
# Sydney              11.7
# Williamtown         12.0
# ...

# %%
group_loc['MaxTemp'].max().sort_values(ascending=False)
# Out:
# Location
# Woomera             48.1
# Moree               47.3
# Richmond            47.0
# Penrith             46.9
# MelbourneAirport    46.8
# Watsonia            46.7
# Mildura             46.7
# Cobar               46.6
# BadgerysCreek       46.4
# Melbourne           46.4
# SydneyAirport       46.4
# SalmonGums          46.3
# Sydney              45.8
# Adelaide            45.7
# Williamtown         45.5
# Bendigo             45.4
# PearceRAAF          45.4
# Nhil                45.3
# WaggaWagga          45.2
# AliceSprings        44.9
# MountGambier        44.9
# Albury              44.8
# Uluru               44.4
# Perth               44.4
# Sale                44.4
# Dartmoor            44.4
# PerthAirport        44.2
# Nuriootpa           44.1
# Ballarat            44.1
# Newcastle           44.1
# NorahHead           44.0
# Portland            42.5
# Wollongong          42.4
# Canberra            42.0
# Katherine           42.0
# Hobart              41.8
# ...

# %%
group_loc.size().sort_values(ascending=False)
# Out:
# Location
# Canberra            3436
# Sydney              3344
# Adelaide            3193
# Darwin              3193
# Brisbane            3193
# Melbourne           3193
# Perth               3193
# Hobart              3193
# Bendigo             3040
# Ballarat            3040
# Cairns              3040
# GoldCoast           3040
# MountGambier        3040
# MountGinini         3040
# Albany              3040
# AliceSprings        3040
# Albury              3040
# Townsville          3040
# Wollongong          3040
# Launceston          3040
# Tuggeranong         3039
# Penrith             3039
# Newcastle           3039
# BadgerysCreek       3009
# Dartmoor            3009
# Witchcliffe         3009
# Cobar               3009
# CoffsHarbour        3009
# NorfolkIsland       3009
# Moree               3009
# Mildura             3009
# Nuriootpa           3009
# MelbourneAirport    3009
# Woomera             3009
# WaggaWagga          3009
# PerthAirport        3009
# ...

# %% [markdown]
# Наиболее многочисленной группой является Canberra с 3 436 наблюдениями. Наибольшие значения средней максимальной температуры наблюдаются в Darwin (около 32.5 °C) и Katherine (около 34.9 °C). Наименьшая средняя температура в MountGinini (около 11.7 °C).

# %% [markdown]
# 3. Группировка по двум признакам

# %%
group2 = data.groupby(['Location', 'RainToday'])
group2['MaxTemp'].mean().sort_values(ascending=False)
# Out:
# Location     RainToday
# Katherine    No           35.041292
#              Yes          34.381569
# Darwin       No           32.740470
#              Yes          31.993075
# Uluru        No           30.548573
#                             ...
# Hobart       Yes          15.609186
# Portland     Yes          15.144424
# Ballarat     Yes          14.147179
# MountGinini  No           12.988045
#              Yes           8.688213
# Name: MaxTemp, Length: 98, dtype: float64

# %%
group2['MaxTemp'].min().sort_values(ascending=False)
# Out:
# Location     RainToday
# Katherine    Yes          25.5
#              No           25.2
# Darwin       No           24.8
#              Yes          21.9
# Cairns       No           21.5
#                           ...
# Ballarat     Yes           4.6
# Canberra     No            4.1
# Tuggeranong  No            2.6
# MountGinini  No           -2.1
#              Yes          -4.8
# Name: MaxTemp, Length: 98, dtype: float64

# %%
group2['MaxTemp'].max().sort_values(ascending=False)
# Out:
# Location          RainToday
# Woomera           No           48.1
# Moree             No           47.3
# Richmond          No           47.0
# Penrith           No           46.9
# MelbourneAirport  No           46.8
#                                ...
# Launceston        Yes          30.3
# Portland          Yes          29.3
# NorfolkIsland     Yes          28.4
#                   No           28.2
# MountGinini       Yes          26.9
# Name: MaxTemp, Length: 98, dtype: float64

# %%
group2.size().sort_values(ascending=False)
# Out:
# Location      RainToday
# Canberra      No           2789
# Woomera       No           2789
# AliceSprings  No           2788
# Mildura       No           2680
# Cobar         No           2602
#                            ...
# Katherine     Yes           265
# AliceSprings  Yes           244
# Nhil          Yes           242
# Woomera       Yes           202
# Uluru         Yes           116
# Length: 98, dtype: int64

# %% [markdown]
# 4. Рассчет агрегированных показателей.

# %%
group2['MaxTemp'].agg(['mean', 'min', 'max', 'count'])
# Out:
#                             mean   min   max  count
# Location    RainToday
# Adelaide    No         24.435069  11.4  45.7   2401
#             Yes        17.735994  10.8  34.3    689
# Albany      No         21.122900  12.0  39.0   2083
#             Yes        17.546319  11.6  31.0    883
# Albury      No         23.662867   7.5  44.8   2386
# ...                          ...   ...   ...    ...
# Witchcliffe Yes        17.918544  11.5  38.6    879
# Wollongong  No         21.774724  12.2  42.4   2263
#             Yes        20.528973  12.8  40.1    711
# Woomera     No         26.834745  11.3  48.1   2786
#             Yes        22.644059  11.2  43.0    202
#
# [98 rows x 4 columns]

# %% [markdown]
# 1. Во всех локациях средняя максимальная температура в дни без дождя (No) выше, чем в дождливые дни (Yes). Разница составляет от 1.5 до 6.5 °C.
#
# 2. Наиболее большая разница температур между No и Yes наблюдается в засушливых регионах: AliceSprings (3.1 °C), Cobar (3.6 °C), MountGinini (4.3 °C), PearceRAAF (7.3 °C), Perth (6.3 °C), Woomera (4.2 °C).
#
# 3. Наименьшая разница температур в тропических регионах: Brisbane (0.3 °C), Cairns (0.07 °C), Darwin (0.75 °C), Townsville (-0.35 °C). В Townsville средняя температура в дождливые дни даже немного выше.

# %% [markdown]
# Какие комбинации признаков встречаются чаще всего:
#
# 1. Canberra - No: 2 786 наблюдений
# 2. Woomera - No: 2 786 наблюдений
# 3. AliceSprings - No: 2 786 наблюдений
# 4. Sydney - No: 2 469 наблюдений
# 5. MelbourneAirport - No: 2 356 наблюдений
#
# Эти комбинации наиболее многочисленны, поскольку представляют локации с большим общим количеством наблюдений и преобладанием дней без дождя.
#
# Какие группы можно считать аномальными или нетипичными:
#
# 1. Katherine - Yes: всего 255 наблюдений (против 1 269 для No). Это соответствует засушливому климату региона.
#
# 2. Uluru - Yes: всего 116 наблюдений (против 1 402 для No). Крайне засушливый регион.
#
# 3. Woomera - Yes: всего 202 наблюдения (против 2 786 для No). Один из самых засушливых регионов.
#
# 4. Nhil - Yes: 242 наблюдения (против 1 326 для No).
#
# 5. MountGinini - Yes: имеет аномально низкую среднюю максимальную температуру (8.69 °C) по сравнению с другими локациями. Это самая холодная локация в датасете.
#
# 6. Darwin - Yes и Darwin - No: имеют самые высокие температуры в датасете (31.99 и 32.74 °C соответственно), что соответствует тропическому климату.
#
# 7. NorfolkIsland - Yes и No: имеют наименьший разброс температур (от 15.2 до 28.4 °C), что характерно для островного климата.

# %% [markdown]
# ## Повышенный уровень

# %%
#Создаем две таблицы
data1 = data.head(10)
data2 = data.tail(10)

data1, data2
# Out:
# (         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
#  0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
#  1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
#  2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
#  3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
#  4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#  5  2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
#  6  2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
#  7  2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
#  8  2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
#  9  2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
#
#    WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# ...

# %%
#Объединяем две таблицы
data33 = pd.concat([data1, data2])
data33
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# 5       2008-12-06   Albury     14.6     29.7       0.2          NaN
# 6       2008-12-07   Albury     14.3     25.0       0.0          NaN
# 7       2008-12-08   Albury      7.7     26.7       0.0          NaN
# 8       2008-12-09   Albury      9.7     31.9       0.0          NaN
# 9       2008-12-10   Albury     13.1     30.1       1.4          NaN
# 145450  2017-06-16    Uluru      5.2     24.3       0.0          NaN
# 145451  2017-06-17    Uluru      6.4     23.4       0.0          NaN
# 145452  2017-06-18    Uluru      8.0     20.7       0.0          NaN
# ...

# %%
#Проверяем размеры
data33.shape
# Out:
# (20, 23)

# %%
#Смотрим пропущенные значения
data33.describe()
# Out:
#          MinTemp    MaxTemp   Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# count  20.000000  19.000000  20.000000          0.0       0.0      19.000000
# mean    9.240000  25.831579   0.160000          NaN       NaN      38.315789
# std     4.343949   3.448519   0.387162          NaN       NaN      13.739855
# min     2.800000  20.600000   0.000000          NaN       NaN      22.000000
# 25%     6.150000  23.400000   0.000000          NaN       NaN      29.500000
# 50%     7.900000  25.300000   0.000000          NaN       NaN      35.000000
# 75%    13.175000  27.500000   0.000000          NaN       NaN      44.000000
# max    17.500000  32.300000   1.400000          NaN       NaN      80.000000
#
#        WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# count     20.000000     20.000000    20.000000    20.000000    20.000000
# mean      13.400000     17.100000    54.450000    24.650000  1017.035000
# ...

# %%
data33.describe(include='O')
# Out:
#               Date Location WindGustDir WindDir9am WindDir3pm RainToday  \
# count           20       20          19         20         20        20
# unique          20        2           9          8          9         2
# top     2008-12-01   Albury           W         SE          E        No
# freq             1       10           5          7          5        19
#
#        RainTomorrow
# count            19
# unique            2
# top              No
# freq             18

# %% [markdown]
# Объединение было выполнено с помощью функции `pd.concat()`. В данном случае ключ объединения не использовался, так как таблицы были добавлены друг под друга по одинаковым столбцам.
#
# К исходной таблице `data1`, содержащей первые 10 строк, были добавлены строки из таблицы `data2`, содержащей последние 10 строк исходного набора данных.
#
# В итоговой таблице могут присутствовать пропущенные значения. Они возникли не из-за объединения, а уже содержались в исходном датасете. Например, пропуски могут быть в признаках `Evaporation`, `Sunshine`, `Cloud9am`, `Cloud3pm`, а также в данных о направлении и скорости ветра.

# %% [markdown]
# ## Описание структурных данных

# %% [markdown]
# Исходная таблица содержит данные о погоде в различных городах Австралии. Каждая строка представляет наблюдение за погодой в определённой локации в конкретную дату. В таблице представлены 145 460 строк и 23 столбца. Признаки включают минимальную и максимальную температуру, количество осадков, влажность, атмосферное давление, облачность, скорость и направление ветра. Также в датасете есть категориальные признаки `Location`, `WindGustDir`, `WindDir9am` и `WindDir3pm`. Столбцы `RainToday` и `RainTomorrow` содержат бинарные значения `Yes` и `No`, которые показывают наличие дождя сегодня и на следующий день. Столбец `Date` содержит дату наблюдения. В числовых признаках присутствуют пропущенные значения, особенно в столбцах `Evaporation`, `Sunshine`, `Cloud9am` и `Cloud3pm`. Для первичного анализа данных наиболее полезными оказались функции `head()`, `shape`, `dtypes` и `describe()`. Функция `head()` позволила просмотреть первые строки таблицы, а `shape` определить её размерность. Метод `describe()` помог получить минимальные, максимальные и средние значения числовых признаков, а также стандартное отклонение. Для работы с категориальными признаками использовался метод `describe(include='O')`. Операция фильтрации позволила выбрать строки с количеством осадков больше заданного значения. Метод `sort_values()` использовался для сортировки данных по возрастанию и убыванию. Группировка `groupby()` и агрегация `agg()` позволили сравнить погодные показатели между разными локациями.

# %% [markdown]
# ## Выводы

# %% [markdown]
# Распределение данных показывает, что большинство наблюдений относится к дням без дождя: значение `No` встречается чаще, чем `Yes` в столбцах `RainToday` и `RainTomorrow`. Распределение осадков неравномерное: медиана `Rainfall` равна 0 мм, однако максимальное значение достигает 371 мм. Это означает, что в большинстве дней осадков не было, но в выборке присутствуют редкие дни с очень сильными дождями. Влажность, скорость ветра и количество осадков имеют более заметный разброс, чем облачность и продолжительность солнечного сияния.
#
# Между локациями наблюдаются существенные различия. Самой многочисленной группой является Canberra, содержащая 3 436 наблюдений. Наиболее высокие средние максимальные температуры характерны для северных городов: Darwin, Katherine, Cairns и Townsville. Наиболее низкие температуры наблюдаются в MountGinini, Canberra, Hobart и Ballarat. В группах с `RainToday = No` средняя максимальная температура обычно выше, чем в группах с `RainToday = Yes`.
#
# Качество и полнота данных неоднородны. В столбцах `Date` и `Location` пропуски отсутствуют, поэтому каждое наблюдение можно связать с датой и местом. Наибольшее число пропусков содержат `Sunshine`, `Evaporation`, `Cloud9am` и `Cloud3pm`. Также имеются пропуски в направлениях ветра, скорости ветра, давлении и целевой переменной `RainTomorrow`. Перед дальнейшим анализом или построением модели пропуски следует обработать: удалить отдельные строки, заполнить значения или исключить признаки с большим количеством отсутствующих данных.

# %% [markdown]
# ## СПАСИБО ЗА ПРОСМОТР МОЕГО ИНТЕРКАТИВНОГО ОТЧЕТА
#
# ![b5e602617960aa1a10e2d75172c9fc7d.jpg](data:image/jpeg;base64,...)
